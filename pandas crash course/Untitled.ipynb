# %%
import pandas as pd

# %%
#main components of pd
 #series
 #dataframe

# %%
data={
    'Maths':[49, 45, 48, 42],
    'Physics':[42,44,41,38]
}

# %%
#show data and type of data

# %%
print(data)
print(type(data))
# Out:
# {'Maths': [49, 45, 48, 42], 'Physics': [42, 44, 41, 38]}
# <class 'dict'>

# %%
#creating a data frame

# %%
df=pd.DataFrame(data)
df
# Out:
#    Maths  Physics
# 0     49       42
# 1     45       44
# 2     48       41
# 3     42       38

# %%
df['Maths']
# Out:
# 0    49
# 1    45
# 2    48
# 3    42
# Name: Maths, dtype: int64

# %%
type(df['Maths'])
# Out:
# pandas.core.series.Series

# %%
#to read a csv file

# %%
data1=pd.read_csv('realestate.csv')
data1
# Out:
#       No  X1 transaction date  X2 house age  \
# 0      1             2012.917          32.0
# 1      2             2012.917          19.5
# 2      3             2013.583          13.3
# 3      4             2013.500          13.3
# 4      5             2012.833           5.0
# ..   ...                  ...           ...
# 409  410             2013.000          13.7
# 410  411             2012.667           5.6
# 411  412             2013.250          18.8
# 412  413             2013.000           8.1
# 413  414             2013.500           6.5
#
#      X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                  84.87882                               10
# 1                                 306.59470                                9
# 2                                 561.98450                                5
# 3                                 561.98450                                5
# ...

# %%
#to read an excel file

# %%
data2=pd.read_excel('autoinsurance.xls')
data2
# Out:
# *** No CODEPAGE record, no encoding_override: will use 'ascii'
#       X      Y
# 0   108  392.5
# 1    19   46.2
# 2    13   15.7
# 3   124  422.2
# 4    40  119.4
# ..  ...    ...
# 58    9   87.4
# 59   31  209.8
# 60   14   95.5
# 61   53  244.6
# 62   26  187.5
#
# [63 rows x 2 columns]

# %%
data1.head(2)
# Out:
#    No  X1 transaction date  X2 house age  \
# 0   1             2012.917          32.0
# 1   2             2012.917          19.5
#
#    X3 distance to the nearest MRT station  X4 number of convenience stores  \
# 0                                84.87882                               10
# 1                               306.59470                                9
#
#    X5 latitude  X6 longitude  Y house price of unit area
# 0     24.98298     121.54024                        37.9
# 1     24.98034     121.53951                        42.2

# %%
data2.head(6)
# Out:
#      X      Y
# 0  108  392.5
# 1   19   46.2
# 2   13   15.7
# 3  124  422.2
# 4   40  119.4
# 5   57  170.9

# %%
#to make a column as index

# %%
data2=pd.read_csv('realestate.csv',index_col='X1 transaction date')
data2.head()
# Out:
#                      No  X2 house age  X3 distance to the nearest MRT station  \
# X1 transaction date
# 2012.917              1          32.0                                84.87882
# 2012.917              2          19.5                               306.59470
# 2013.583              3          13.3                               561.98450
# 2013.500              4          13.3                               561.98450
# 2012.833              5           5.0                               390.56840
#
#                      X4 number of convenience stores  X5 latitude  \
# X1 transaction date
# 2012.917                                          10     24.98298
# 2012.917                                           9     24.98034
# 2013.583                                           5     24.98746
# 2013.500                                           5     24.98746
# 2012.833                                           5     24.97937
#
# ...

# %%
data2.tail()
# Out:
#                       No  X2 house age  \
# X1 transaction date
# 2013.000             410          13.7
# 2012.667             411           5.6
# 2013.250             412          18.8
# 2013.000             413           8.1
# 2013.500             414           6.5
#
#                      X3 distance to the nearest MRT station  \
# X1 transaction date
# 2013.000                                         4082.01500
# 2012.667                                           90.45606
# 2013.250                                          390.96960
# 2013.000                                          104.81010
# 2013.500                                           90.45606
#
#                      X4 number of convenience stores  X5 latitude  \
# X1 transaction date
# 2013.000                                           0     24.94155
# 2012.667                                           9     24.97433
# 2013.250                                           7     24.97923
# ...

# %%
data2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Float64Index: 414 entries, 2012.9170000000001 to 2013.5
# Data columns (total 7 columns):
#  #   Column                                  Non-Null Count  Dtype
# ---  ------                                  --------------  -----
#  0   No                                      414 non-null    int64
#  1   X2 house age                            414 non-null    float64
#  2   X3 distance to the nearest MRT station  414 non-null    float64
#  3   X4 number of convenience stores         414 non-null    int64
#  4   X5 latitude                             414 non-null    float64
#  5   X6 longitude                            414 non-null    float64
#  6   Y house price of unit area              414 non-null    float64
# dtypes: float64(5), int64(2)
# memory usage: 25.9 KB

# %%
#dimensions of data

# %%
data2.shape
# Out:
# (414, 7)

# %%
#to check if there are any null values or duplicate values

# %%
data2.isnull()
# Out:
#                         No  X2 house age  \
# X1 transaction date
# 2012.917             False         False
# 2012.917             False         False
# 2013.583             False         False
# 2013.500             False         False
# 2012.833             False         False
# ...                    ...           ...
# 2013.000             False         False
# 2012.667             False         False
# 2013.250             False         False
# 2013.000             False         False
# 2013.500             False         False
#
#                      X3 distance to the nearest MRT station  \
# X1 transaction date
# 2012.917                                              False
# 2012.917                                              False
# 2013.583                                              False
# 2013.500                                              False
# 2012.833                                              False
# ...

# %%
sum(df.duplicated())
# Out:
# 0

# %%
#to add extra rows

# %%
data_2=data2.append(data2)
data_2
# Out:
#                       No  X2 house age  \
# X1 transaction date
# 2012.917               1          32.0
# 2012.917               2          19.5
# 2013.583               3          13.3
# 2013.500               4          13.3
# 2012.833               5           5.0
# ...                  ...           ...
# 2013.000             410          13.7
# 2012.667             411           5.6
# 2013.250             412          18.8
# 2013.000             413           8.1
# 2013.500             414           6.5
#
#                      X3 distance to the nearest MRT station  \
# X1 transaction date
# 2012.917                                           84.87882
# 2012.917                                          306.59470
# 2013.583                                          561.98450
# 2013.500                                          561.98450
# 2012.833                                          390.56840
# ...                                                     ...
# ...

# %%
sum(data_2.duplicated())
# Out:
# 414

# %%
#to remove duplicates if any

# %%
dt=data_2.drop_duplicates()
dt.shape
# Out:
# (414, 7)

# %%
data_2.shape
# Out:
# (828, 7)

# %%
#column cleanup

# %%
col=dt.columns
col
# Out:
# Index(['No', 'X2 house age', 'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
dt.describe()
# Out:
#                No  X2 house age  X3 distance to the nearest MRT station  \
# count  414.000000    414.000000                              414.000000
# mean   207.500000     17.712560                             1083.885689
# std    119.655756     11.392485                             1262.109595
# min      1.000000      0.000000                               23.382840
# 25%    104.250000      9.025000                              289.324800
# 50%    207.500000     16.100000                              492.231300
# 75%    310.750000     28.150000                             1454.279000
# max    414.000000     43.800000                             6488.021000
#
#        X4 number of convenience stores  X5 latitude  X6 longitude  \
# count                       414.000000   414.000000    414.000000
# mean                          4.094203    24.969030    121.533361
# std                           2.945562     0.012410      0.015347
# ...

# %%
type(list(col))
# Out:
# list

# %%
col1=['a','b','c','d','e','f','g']

# %%
dt.columns=col1
dt
# Out:
#                        a     b           c   d         e          f     g
# X1 transaction date
# 2012.917               1  32.0    84.87882  10  24.98298  121.54024  37.9
# 2012.917               2  19.5   306.59470   9  24.98034  121.53951  42.2
# 2013.583               3  13.3   561.98450   5  24.98746  121.54391  47.3
# 2013.500               4  13.3   561.98450   5  24.98746  121.54391  54.8
# 2012.833               5   5.0   390.56840   5  24.97937  121.54245  43.1
# ...                  ...   ...         ...  ..       ...        ...   ...
# 2013.000             410  13.7  4082.01500   0  24.94155  121.50381  15.4
# 2012.667             411   5.6    90.45606   9  24.97433  121.54310  50.0
# 2013.250             412  18.8   390.96960   7  24.97923  121.53986  40.6
# 2013.000             413   8.1   104.81010   5  24.96674  121.54067  52.5
# 2013.500             414   6.5    90.45606   9  24.97433  121.54310  63.9
#
# [414 rows x 7 columns]

# %%
dt.columns=col
dt
# Out:
#                       No  X2 house age  \
# X1 transaction date
# 2012.917               1          32.0
# 2012.917               2          19.5
# 2013.583               3          13.3
# 2013.500               4          13.3
# 2012.833               5           5.0
# ...                  ...           ...
# 2013.000             410          13.7
# 2012.667             411           5.6
# 2013.250             412          18.8
# 2013.000             413           8.1
# 2013.500             414           6.5
#
#                      X3 distance to the nearest MRT station  \
# X1 transaction date
# 2012.917                                           84.87882
# 2012.917                                          306.59470
# 2013.583                                          561.98450
# 2013.500                                          561.98450
# 2012.833                                          390.56840
# ...                                                     ...
# ...

# %%
dt.rename(
    columns={'No':'Number'}
)
# Out:
#                      Number  X2 house age  \
# X1 transaction date
# 2012.917                  1          32.0
# 2012.917                  2          19.5
# 2013.583                  3          13.3
# 2013.500                  4          13.3
# 2012.833                  5           5.0
# ...                     ...           ...
# 2013.000                410          13.7
# 2012.667                411           5.6
# 2013.250                412          18.8
# 2013.000                413           8.1
# 2013.500                414           6.5
#
#                      X3 distance to the nearest MRT station  \
# X1 transaction date
# 2012.917                                           84.87882
# 2012.917                                          306.59470
# 2013.583                                          561.98450
# 2013.500                                          561.98450
# 2012.833                                          390.56840
# ...

# %%
dt.columns
# Out:
# Index(['No', 'X2 house age', 'X3 distance to the nearest MRT station',
#        'X4 number of convenience stores', 'X5 latitude', 'X6 longitude',
#        'Y house price of unit area'],
#       dtype='object')

# %%
#corr methods

# %%
corrmat=dt.corr()

# %%
corrmat
# Out:
#                                               No  X2 house age  \
# No                                      1.000000     -0.032808
# X2 house age                           -0.032808      1.000000
# X3 distance to the nearest MRT station -0.013573      0.025622
# X4 number of convenience stores        -0.012699      0.049593
# X5 latitude                            -0.010110      0.054420
# X6 longitude                           -0.011059     -0.048520
# Y house price of unit area             -0.028587     -0.210567
#
#                                         X3 distance to the nearest MRT station  \
# No                                                                   -0.013573
# X2 house age                                                          0.025622
# X3 distance to the nearest MRT station                                1.000000
# X4 number of convenience stores                                      -0.602519
# ...

# %%
import seaborn as sns
sns.heatmap(corrmat)

# %%
import matplotlib.pyplot as plt
dt.plot(kind='scatter',x='X5 latitude',y='Y house price of unit area',title='latitude vs price')

# %%
dt.plot(kind='hist',x='X2 house age',y='Y house price of unit area',title='age vs price')
